# %%
import math

# %%
#Give a range to check the property 
minNum = int(input("Please Enter the Minimum integer Value : "))
maxNum = int(input("Please Enter the Maximum integer Value : "))
# Out:
# Please Enter the Minimum integer Value : 100000
# Please Enter the Maximum integer Value : 999999

# %%
#initialize an array 
listN= []

#find all the perfect squares in the range 

for i in range(minNum, maxNum):
    rooot = math.sqrt(i)
    if int(rooot + 0.5) ** 2 == i:
        listN.append(i)

#print all the perfect squares saved in listN1 
print(listN)
# Out:
# [100489, 101124, 101761, 102400, 103041, 103684, 104329, 104976, 105625, 106276, 106929, 107584, 108241, 108900, 109561, 110224, 110889, 111556, 112225, 112896, 113569, 114244, 114921, 115600, 116281, 116964, 117649, 118336, 119025, 119716, 120409, 121104, 121801, 122500, 123201, 123904, 124609, 125316, 126025, 126736, 127449, 128164, 128881, 129600, 130321, 131044, 131769, 132496, 133225, 133956, 134689, 135424, 136161, 136900, 137641, 138384, 139129, 139876, 140625, 141376, 142129, 142884, 143641, 144400, 145161, 145924, 146689, 147456, 148225, 148996, 149769, 150544, 151321, 152100, 152881, 153664, 154449, 155236, 156025, 156816, 157609, 158404, 159201, 160000, 160801, 161604, 162409, 163216, 164025, 164836, 165649, 166464, 167281, 168100, 168921, 169744, 170569, 171396, 172225, 173056, 173889, 174724, 175561, 176400, 177241, 178084, 178929, 179776, 180625, 181476, 182329, 183184, 184041, 184900, 185761, 186624, 187489, 188356, 189225, 190096, 190969, 191844, 192721, 193600, 194481, 195364, 196249, 197136, 198025, 198916, 199809, 200704, 201601, 202500, 203401, 204304, 205209, 206116, 207025, 207936, 208849, 209764, 210681, 211600, 212521, 213444, 214369, 215296, 216225, 217156, 218089, 219024, 219961, 220900, 221841, 222784, 223729, 224676, 225625, 226576, 227529, 228484, 229441, 230400, 231361, 232324, 233289, 234256, 235225, 236196, 237169, 238144, 239121, 240100, 241081, 242064, 243049, 244036, 245025, 246016, 247009, 248004, 249001, 250000, 251001, 252004, 253009, 254016, 255025, 256036, 257049, 258064, 259081, 260100, 261121, 262144, 263169, 264196, 265225, 266256, 267289, 268324, 269361, 270400, 271441, 272484, 273529, 274576, 275625, 276676, 277729, 278784, 279841, 280900, 281961, 283024, 284089, 285156, 286225, 287296, 288369, 289444, 290521, 291600, 292681, 293764, 294849, 295936, 297025, 298116, 299209, 300304, 301401, 302500, 303601, 304704, 305809, 306916, 308025, 309136, 310249, 311364, 312481, 313600, 314721, 315844, 316969, 318096, 319225, 320356, 321489, 322624, 323761, 324900, 326041, 327184, 328329, 329476, 330625, 331776, 332929, 334084, 335241, 336400, 337561, 338724, 339889, 341056, 342225, 343396, 344569, 345744, 346921, 348100, 349281, 350464, 351649, 352836, 354025, 355216, 356409, 357604, 358801, 360000, 361201, 362404, 363609, 364816, 366025, 367236, 368449, 369664, 370881, 372100, 373321, 374544, 375769, 376996, 378225, 379456, 380689, 381924, 383161, 384400, 385641, 386884, 388129, 389376, 390625, 391876, 393129, 394384, 395641, 396900, 398161, 399424, 400689, 401956, 403225, 404496, 405769, 407044, 408321, 409600, 410881, 412164, 413449, 414736, 416025, 417316, 418609, 419904, 421201, 422500, 423801, 425104, 426409, 427716, 429025, 430336, 431649, 432964, 434281, 435600, 436921, 438244, 439569, 440896, 442225, 443556, 444889, 446224, 447561, 448900, 450241, 451584, 452929, 454276, 455625, 456976, 458329, 459684, 461041, 462400, 463761, 465124, 466489, 467856, 469225, 470596, 471969, 473344, 474721, 476100, 477481, 478864, 480249, 481636, 483025, 484416, 485809, 487204, 488601, 490000, 491401, 492804, 494209, 495616, 497025, 498436, 499849, 501264, 502681, 504100, 505521, 506944, 508369, 509796, 511225, 512656, 514089, 515524, 516961, 518400, 519841, 521284, 522729, 524176, 525625, 527076, 528529, 529984, 531441, 532900, 534361, 535824, 537289, 538756, 540225, 541696, 543169, 544644, 546121, 547600, 549081, 550564, 552049, 553536, 555025, 556516, 558009, 559504, 561001, 562500, 564001, 565504, 567009, 568516, 570025, 571536, 573049, 574564, 576081, 577600, 579121, 580644, 582169, 583696, 585225, 586756, 588289, 589824, 591361, 592900, 594441, 595984, 597529, 599076, 600625, 602176, 603729, 605284, 606841, 608400, 609961, 611524, 613089, 614656, 616225, 617796, 619369, 620944, 622521, 624100, 625681, 627264, 628849, 630436, 632025, 633616, 635209, 636804, 638401, 640000, 641601, 643204, 644809, 646416, 648025, 649636, 651249, 652864, 654481, 656100, 657721, 659344, 660969, 662596, 664225, 665856, ...

# %%
#length of the list
K = len(listN)
i =0

while i<=K:
 value1= str(listN[i])
 print("The number is : " + str(value1))
 length = len(str(value1))

 #initializing substring
 j =int(length/2) 
 res1 = [int(value1[idx : idx + j]) for idx in range(0, length, j)]
 # seperate the splitted integers 
 x = res1[0] 
 y = res1[1]
 #result 2 
 res2 = pow((x+y), 2)
 print ("(x+y)^2 : " + str(res2)) 
 #verify the result 

 if int(res2)== int(value1):
  print ("true")
 
 i +=1
# Out:
# The number is : 100489
# (x+y)^2 : 346921
# The number is : 101124
# (x+y)^2 : 50625
# The number is : 101761
# (x+y)^2 : 743044
# The number is : 102400
# (x+y)^2 : 252004
# The number is : 103041
# (x+y)^2 : 20736
# The number is : 103684
# (x+y)^2 : 619369
# The number is : 104329
# (x+y)^2 : 187489
# The number is : 104976
# (x+y)^2 : 1166400
# The number is : 105625
# (x+y)^2 : 532900
# The number is : 106276
# (x+y)^2 : 145924
# The number is : 106929
# (x+y)^2 : 1071225
# The number is : 107584
# (x+y)^2 : 477481
# The number is : 108241
# (x+y)^2 : 121801
# The number is : 108900
# (x+y)^2 : 1016064
# The number is : 109561
# (x+y)^2 : 448900
# The number is : 110224
# (x+y)^2 : 111556
# The number is : 110889
# (x+y)^2 : 998001
# The number is : 111556
# (x+y)^2 : 444889
# The number is : 112225
# (x+y)^2 : 113569
# The number is : 112896
# (x+y)^2 : 1016064
# The number is : 113569
# (x+y)^2 : 465124
# The number is : 114244
# (x+y)^2 : 128164
# The number is : 114921
# (x+y)^2 : 1071225
# The number is : 115600
# (x+y)^2 : 511225
# The number is : 116281
# (x+y)^2 : 157609
# The number is : 116964
# (x+y)^2 : 1166400
# The number is : 117649
# (x+y)^2 : 586756
# The number is : 118336
# (x+y)^2 : 206116
# The number is : 119025
# (x+y)^2 : 20736
# The number is : 119716
# (x+y)^2 : 697225
# The number is : 120409
# (x+y)^2 : 279841
# The number is : 121104
# (x+y)^2 : 50625
# The number is : 121801
# (x+y)^2 : 850084
# The number is : 122500
# (x+y)^2 : 386884
# The number is : 123201
# (x+y)^2 : 104976
# The number is : 123904
# (x+y)^2 : 1054729
# The number is : 124609
# (x+y)^2 : 537289
# The number is : 125316
# (x+y)^2 : 194481
# The number is : 126025
# (x+y)^2 : 22801
# The number is : 126736
# (x+y)^2 : 743044
# The number is : 127449
# (x+y)^2 : 331776
# The number is : 128164
# (x+y)^2 : 85264
# The number is : 128881
# (x+y)^2 : 1018081
# The number is : 129600
# (x+y)^2 : 531441
# The number is : 130321
# (x+y)^2 : 203401
# The number is : 131044
# (x+y)^2 : 30625
# The number is : 131769
# (x+y)^2 : 810000
# The number is : 132496
# (x+y)^2 : 394384
# The number is : 133225
# (x+y)^2 : 128164
# The number is : 133956
# (x+y)^2 : 1185921
# The number is : 134689
# (x+y)^2 : 677329
# The number is : 135424
# (x+y)^2 : 312481
# The number is : 136161
# (x+y)^2 : 88209
# The number is : 136900
# (x+y)^2 : 1073296
# The number is : 137641
# (x+y)^2 : 605284
# The number is : 138384
# (x+y)^2 : 272484
# The number is : 139129
# (x+y)^2 : 71824
# The number is : 139876
# (x+y)^2 : 1030225
# The number is : 140625
# (x+y)^2 : 585225
# The number is : 141376
# (x+y)^2 : 267289
# The number is : 142129
# (x+y)^2 : 73441
# The number is : 142884
# (x+y)^2 : 1052676
# The number is : 143641
# (x+y)^2 : 614656
# The number is : 144400
# (x+y)^2 : 295936
# The number is : 145161
# (x+y)^2 : 93636
# The number is : 145924
# (x+y)^2 : 1142761
# The number is : 146689
# (x+y)^2 : 697225
# The number is : 147456
# (x+y)^2 : 363609
# The number is : 148225
# (x+y)^2 : 139129
# The number is : 148996
# (x+y)^2 : 1308736
# The number is : 149769
# (x+y)^2 : 842724
# The number is : 150544
# (x+y)^2 : 481636
# The number is : 151321
# (x+y)^2 : 222784
# The number is : 152100
# (x+y)^2 : 63504
# The number is : 152881
# (x+y)^2 : 1067089
# The number is : 153664
# (x+y)^2 : 667489
# The number is : 154449
# (x+y)^2 : 363609
# The number is : 155236
# (x+y)^2 : 152881
# The number is : 156025
# (x+y)^2 : 32761
# The number is : 156816
# (x+y)^2 : 944784
# The number is : 157609
# (x+y)^2 : 586756
# The number is : 158404
# (x+y)^2 : 315844
# The number is : 159201
# (x+y)^2 : 129600
# The number is : 160000
# (x+y)^2 : 25600
# The number is : 160801
# (x+y)^2 : 923521
# The number is : 161604
# (x+y)^2 : 585225
# The number is : 162409
# (x+y)^2 : 326041
# The number is : 163216
# (x+y)^2 : 143641
# The number is : 164025
# (x+y)^2 : 35721
# The number is : 164836
# (x+y)^2 : 1000000
# The number is : 165649
# (x+y)^2 : 662596
# The number is : 166464
# (x+y)^2 : 396900
# The number is : 167281
# (x+y)^2 : 200704
# The number is : 168100
# (x+y)^2 : 71824
# The number is : 168921
# (x+y)^2 : 1185921
# The number is : 169744
# (x+y)^2 : 833569
# The number is : 170569
# (x+y)^2 : 546121
# The number is : 171396
# (x+y)^2 : 321489
# The number is : 172225
# (x+y)^2 : 157609
# The number is : 173056
# (x+y)^2 : 52441
# The number is : 173889
# (x+y)^2 : 1127844
# The number is : 174724
# (x+y)^2 : 806404
# The number is : 175561
# (x+y)^2 : 541696
# The number is : 176400
# (x+y)^2 : 331776
# The number is : 177241
# (x+y)^2 : 174724
# The number is : 178084
# (x+y)^2 : 68644
# The number is : 178929
# (x+y)^2 : 1225449
# The number is : 179776
# (x+y)^2 : 912025
# The number is : 180625
# (x+y)^2 : 648025
# The number is : 181476
# (x+y)^2 : 431649
# The number is : 182329
# (x+y)^2 : 261121
# The number is : 183184
# (x+y)^2 : 134689
# The number is : 184041
# (x+y)^2 : 50625
# The number is : 184900
# (x+y)^2 : 1175056
# The number is : 185761
# (x+y)^2 : 894916
# The number is : 186624
# (x+y)^2 : 656100
# The number is : 187489
# (x+y)^2 : 456976
# The number is : 188356
# (x+y)^2 : 295936
# The number is : 189225
# (x+y)^2 : 171396
# The number is : 190096
# (x+y)^2 : 81796
# The number is : 190969
# (x+y)^2 : 1343281
# The number is : 191844
# (x+y)^2 : 1071225
# The number is : 192721
# (x+y)^2 : 833569
# The number is : 193600
# (x+y)^2 : 628849
# The number is : 194481
# (x+y)^2 : 455625
# The number is : 195364
# (x+y)^2 : 312481
# The number is : 196249
# (x+y)^2 : 198025
# The number is : 197136
# (x+y)^2 : 110889
# The number is : 198025
# (x+y)^2 : 49729
# The number is : 198916
# (x+y)^2 : 1240996
# The number is : 199809
# (x+y)^2 : 1016064
# The number is : 200704
# (x+y)^2 : 817216
# The number is : 201601
# (x+y)^2 : 643204
# The number is : 202500
# (x+y)^2 : 492804
# The number is : 203401
# (x+y)^2 : 364816
# The number is : 204304
# (x+y)^2 : 258064
# The number is : 205209
# (x+y)^2 : 171396
# The number is : 206116
# (x+y)^2 : 103684
# The number is : 207025
# (x+y)^2 : 53824
# The number is : 207936
# (x+y)^2 : 1306449
# The number is : 208849
# (x+y)^2 : 1117249
# The number is : 209764
# (x+y)^2 : 946729
# The number is : 210681
# (x+y)^2 : 793881
# The number is : 211600
# (x+y)^2 : 657721
# The number is : 212521
# (x+y)^2 : 537289
# The number is : 213444
# (x+y)^2 : 431649
# The number is : 214369
# (x+y)^2 : 339889
# The number is : 215296
# (x+y)^2 : 261121
# The number is : 216225
# (x+y)^2 : 194481
# The number is : 217156
# (x+y)^2 : 139129
# The number is : 218089
# (x+y)^2 : 94249
# The number is : 219024
# (x+y)^2 : 59049
# The number is : 219961
# (x+y)^2 : 1392400
# The number is : 220900
# (x+y)^2 : 1254400
# The number is : 221841
# (x+y)^2 : 1127844
# The number is : 222784
# (x+y)^2 : 1012036
# The number is : 223729
# (x+y)^2 : 906304
# The number is : 224676
# (x+y)^2 : 810000
# The number is : 225625
# (x+y)^2 : 722500
# The number is : 226576
# (x+y)^2 : 643204
# The number is : 227529
# (x+y)^2 : 571536
# The number is : 228484
# (x+y)^2 : 506944
# The number is : 229441
# (x+y)^2 : 448900
# The number is : 230400
# (x+y)^2 : 396900
# The number is : 231361
# (x+y)^2 : 350464
# The number is : 232324
# (x+y)^2 : 309136
# The number is : 233289
# (x+y)^2 : 272484
# The number is : 234256
# (x+y)^2 : 240100
# The number is : 235225
# (x+y)^2 : 211600
# The number is : 236196
# (x+y)^2 : 186624
# The number is : 237169
# (x+y)^2 : 164836
# The number is : 238144
# (x+y)^2 : 145924
# The number is : 239121
# (x+y)^2 : 129600
# The number is : 240100
# (x+y)^2 : 115600
# The number is : 241081
# (x+y)^2 : 103684
# The number is : 242064
# (x+y)^2 : 93636
# The number is : 243049
# (x+y)^2 : 85264
# The number is : 244036
# (x+y)^2 : 78400
# The number is : 245025
# (x+y)^2 : 72900
# The number is : 246016
# (x+y)^2 : 68644
# The number is : 247009
# (x+y)^2 : 65536
# The number is : 248004
# (x+y)^2 : 63504
# The number is : 249001
# (x+y)^2 : 62500
# The number is : 250000
# (x+y)^2 : 62500
# The number is : 251001
# (x+y)^2 : 63504
# The number is : 252004
# (x+y)^2 : 65536
# The number is : 253009
# (x+y)^2 : 68644
# The number is : 254016
# (x+y)^2 : 72900
# The number is : 255025
# (x+y)^2 : 78400
# The number is : 256036
# (x+y)^2 : 85264
# The number is : 257049
# (x+y)^2 : 93636
# The number is : 258064
# (x+y)^2 : 103684
# The number is : 259081
# (x+y)^2 : 115600
# The number is : 260100
# (x+y)^2 : 129600
# The number is : 261121
# (x+y)^2 : 145924
# The number is : 262144
# (x+y)^2 : 164836
# The number is : 263169
# (x+y)^2 : 186624
# The number is : 264196
# (x+y)^2 : 211600
# The number is : 265225
# (x+y)^2 : 240100
# The number is : 266256
# (x+y)^2 : 272484
# The number is : 267289
# (x+y)^2 : 309136
# The number is : 268324
# (x+y)^2 : 350464
# The number is : 269361
# (x+y)^2 : 396900
# The number is : 270400
# (x+y)^2 : 448900
# The number is : 271441
# (x+y)^2 : 506944
# The number is : 272484
# (x+y)^2 : 571536
# The number is : 273529
# (x+y)^2 : 643204
# The number is : 274576
# (x+y)^2 : 722500
# The number is : 275625
# (x+y)^2 : 810000
# The number is : 276676
# (x+y)^2 : 906304
# The number is : 277729
# (x+y)^2 : 1012036
# The number is : 278784
# (x+y)^2 : 1127844
# The number is : 279841
# (x+y)^2 : 1254400
# The number is : 280900
# (x+y)^2 : 1392400
# The number is : 281961
# (x+y)^2 : 1542564
# The number is : 283024
# (x+y)^2 : 94249
# The number is : 284089
# (x+y)^2 : 139129
# The number is : 285156
# (x+y)^2 : 194481
# The number is : 286225
# (x+y)^2 : 261121
# The number is : 287296
# (x+y)^2 : 339889
# The number is : 288369
# (x+y)^2 : 431649
# The number is : 289444
# (x+y)^2 : 537289
# The number is : 290521
# (x+y)^2 : 657721
# The number is : 291600
# (x+y)^2 : 793881
# The number is : 292681
# (x+y)^2 : 946729
# The number is : 293764
# (x+y)^2 : 1117249
# The number is : 294849
# (x+y)^2 : 1306449
# The number is : 295936
# (x+y)^2 : 1515361
# The number is : 297025
# (x+y)^2 : 103684
# The number is : 298116
# (x+y)^2 : 171396
# The number is : 299209
# (x+y)^2 : 258064
# The number is : 300304
# (x+y)^2 : 364816
# The number is : 301401
# (x+y)^2 : 492804
# The number is : 302500
# (x+y)^2 : 643204
# The number is : 303601
# (x+y)^2 : 817216
# The number is : 304704
# (x+y)^2 : 1016064
# The number is : 305809
# (x+y)^2 : 1240996
# The number is : 306916
# (x+y)^2 : 1493284
# The number is : 308025
# (x+y)^2 : 110889
# The number is : 309136
# (x+y)^2 : 198025
# The number is : 310249
# (x+y)^2 : 312481
# The number is : 311364
# (x+y)^2 : 455625
# The number is : 312481
# (x+y)^2 : 628849
# The number is : 313600
# (x+y)^2 : 833569
# The number is : 314721
# (x+y)^2 : 1071225
# The number is : 315844
# (x+y)^2 : 1343281
# The number is : 316969
# (x+y)^2 : 1651225
# The number is : 318096
# (x+y)^2 : 171396
# The number is : 319225
# (x+y)^2 : 295936
# The number is : 320356
# (x+y)^2 : 456976
# The number is : 321489
# (x+y)^2 : 656100
# The number is : 322624
# (x+y)^2 : 894916
# The number is : 323761
# (x+y)^2 : 1175056
# The number is : 324900
# (x+y)^2 : 1498176
# The number is : 326041
# (x+y)^2 : 134689
# The number is : 327184
# (x+y)^2 : 261121
# The number is : 328329
# (x+y)^2 : 431649
# The number is : 329476
# (x+y)^2 : 648025
# The number is : 330625
# (x+y)^2 : 912025
# The number is : 331776
# (x+y)^2 : 1225449
# The number is : 332929
# (x+y)^2 : 1590121
# The number is : 334084
# (x+y)^2 : 174724
# The number is : 335241
# (x+y)^2 : 331776
# The number is : 336400
# (x+y)^2 : 541696
# The number is : 337561
# (x+y)^2 : 806404
# The number is : 338724
# (x+y)^2 : 1127844
# The number is : 339889
# (x+y)^2 : 1507984
# The number is : 341056
# (x+y)^2 : 157609
# The number is : 342225
# (x+y)^2 : 321489
# The number is : 343396
# (x+y)^2 : 546121
# The number is : 344569
# (x+y)^2 : 833569
# The number is : 345744
# (x+y)^2 : 1185921
# The number is : 346921
# (x+y)^2 : 1605289
# The number is : 348100
# (x+y)^2 : 200704
# The number is : 349281
# (x+y)^2 : 396900
# The number is : 350464
# (x+y)^2 : 662596
# The number is : 351649
# (x+y)^2 : 1000000
# The number is : 352836
# (x+y)^2 : 1411344
# The number is : 354025
# (x+y)^2 : 143641
# The number is : 355216
# (x+y)^2 : 326041
# The number is : 356409
# (x+y)^2 : 585225
# The number is : 357604
# (x+y)^2 : 923521
# The number is : 358801
# (x+y)^2 : 1343281
# The number is : 360000
# (x+y)^2 : 129600
# The number is : 361201
# (x+y)^2 : 315844
# The number is : 362404
# (x+y)^2 : 586756
# The number is : 363609
# (x+y)^2 : 944784
# The number is : 364816
# (x+y)^2 : 1392400
# The number is : 366025
# (x+y)^2 : 152881
# The number is : 367236
# (x+y)^2 : 363609
# The number is : 368449
# (x+y)^2 : 667489
# The number is : 369664
# (x+y)^2 : 1067089
# The number is : 370881
# (x+y)^2 : 1565001
# The number is : 372100
# (x+y)^2 : 222784
# The number is : 373321
# (x+y)^2 : 481636
# The number is : 374544
# (x+y)^2 : 842724
# The number is : 375769
# (x+y)^2 : 1308736
# The number is : 376996
# (x+y)^2 : 1882384
# The number is : 378225
# (x+y)^2 : 363609
# The number is : 379456
# (x+y)^2 : 697225
# The number is : 380689
# (x+y)^2 : 1142761
# The number is : 381924
# (x+y)^2 : 1703025
# The number is : 383161
# (x+y)^2 : 295936
# The number is : 384400
# (x+y)^2 : 614656
# The number is : 385641
# (x+y)^2 : 1052676
# The number is : 386884
# (x+y)^2 : 1612900
# The number is : 388129
# (x+y)^2 : 267289
# The number is : 389376
# (x+y)^2 : 585225
# The number is : 390625
# (x+y)^2 : 1030225
# The number is : 391876
# (x+y)^2 : 1605289
# The number is : 393129
# (x+y)^2 : 272484
# The number is : 394384
# (x+y)^2 : 605284
# The number is : 395641
# (x+y)^2 : 1073296
# The number is : 396900
# (x+y)^2 : 1679616
# The number is : 398161
# (x+y)^2 : 312481
# The number is : 399424
# (x+y)^2 : 677329
# The number is : 400689
# (x+y)^2 : 1185921
# The number is : 401956
# (x+y)^2 : 1841449
# The number is : 403225
# (x+y)^2 : 394384
# The number is : 404496
# (x+y)^2 : 810000
# The number is : 405769
# (x+y)^2 : 1378276
# The number is : 407044
# (x+y)^2 : 203401
# The number is : 408321
# (x+y)^2 : 531441
# The number is : 409600
# (x+y)^2 : 1018081
# The number is : 410881
# (x+y)^2 : 1666681
# The number is : 412164
# (x+y)^2 : 331776
# The number is : 413449
# (x+y)^2 : 743044
# The number is : 414736
# (x+y)^2 : 1322500
# The number is : 416025
# (x+y)^2 : 194481
# The number is : 417316
# (x+y)^2 : 537289
# The number is : 418609
# (x+y)^2 : 1054729
# The number is : 419904
# (x+y)^2 : 1750329
# The number is : 421201
# (x+y)^2 : 386884
# The number is : 422500
# (x+y)^2 : 850084
# The number is : 423801
# (x+y)^2 : 1498176
# The number is : 425104
# (x+y)^2 : 279841
# The number is : 426409
# (x+y)^2 : 697225
# The number is : 427716
# (x+y)^2 : 1306449
# The number is : 429025
# (x+y)^2 : 206116
# The number is : 430336
# (x+y)^2 : 586756
# The number is : 431649
# (x+y)^2 : 1166400
# The number is : 432964
# (x+y)^2 : 1948816
# The number is : 434281
# (x+y)^2 : 511225
# The number is : 435600
# (x+y)^2 : 1071225
# The number is : 436921
# (x+y)^2 : 1841449
# The number is : 438244
# (x+y)^2 : 465124
# The number is : 439569
# (x+y)^2 : 1016064
# The number is : 440896
# (x+y)^2 : 1784896
# The number is : 442225
# (x+y)^2 : 444889
# The number is : 443556
# (x+y)^2 : 998001
# The number is : 444889
# (x+y)^2 : 1776889
# The number is : 446224
# (x+y)^2 : 448900
# The number is : 447561
# (x+y)^2 : 1016064
# The number is : 448900
# (x+y)^2 : 1817104
# The number is : 450241
# (x+y)^2 : 477481
# The number is : 451584
# (x+y)^2 : 1071225
# The number is : 452929
# (x+y)^2 : 1907161
# The number is : 454276
# (x+y)^2 : 532900
# The number is : 455625
# (x+y)^2 : 1166400
# The number is : 456976
# (x+y)^2 : 2050624
# The number is : 458329
# (x+y)^2 : 619369
# The number is : 459684
# (x+y)^2 : 1306449
# The number is : 461041
# (x+y)^2 : 252004
# The number is : 462400
# (x+y)^2 : 743044
# The number is : 463761
# (x+y)^2 : 1498176
# The number is : 465124
# (x+y)^2 : 346921
# The number is : 466489
# (x+y)^2 : 912025
# The number is : 467856
# (x+y)^2 : 1750329
# The number is : 469225
# (x+y)^2 : 481636
# The number is : 470596
# (x+y)^2 : 1136356
# The number is : 471969
# (x+y)^2 : 2073600
# The number is : 473344
# (x+y)^2 : 667489
# The number is : 474721
# (x+y)^2 : 1428025
# The number is : 476100
# (x+y)^2 : 331776
# The number is : 477481
# (x+y)^2 : 917764
# The number is : 478864
# (x+y)^2 : 1800964
# The number is : 480249
# (x+y)^2 : 531441
# The number is : 481636
# (x+y)^2 : 1247689
# The number is : 483025
# (x+y)^2 : 258064
# The number is : 484416
# (x+y)^2 : 810000
# The number is : 485809
# (x+y)^2 : 1674436
# The number is : 487204
# (x+y)^2 : 477481
# The number is : 488601
# (x+y)^2 : 1185921
# The number is : 490000
# (x+y)^2 : 240100
# The number is : 491401
# (x+y)^2 : 795664
# The number is : 492804
# (x+y)^2 : 1679616
# The number is : 494209
# (x+y)^2 : 494209
# true
# The number is : 495616
# (x+y)^2 : 1234321
# The number is : 497025
# (x+y)^2 : 272484
# The number is : 498436
# (x+y)^2 : 872356
# The number is : 499849
# (x+y)^2 : 1817104
# The number is : 501264
# (x+y)^2 : 585225
# The number is : 502681
# (x+y)^2 : 1399489
# The number is : 504100
# (x+y)^2 : 364816
# The number is : 505521
# (x+y)^2 : 1052676
# The number is : 506944
# (x+y)^2 : 2102500
# The number is : 508369
# (x+y)^2 : 769129
# The number is : 509796
# (x+y)^2 : 1703025
# The number is : 511225
# (x+y)^2 : 541696
# The number is : 512656
# (x+y)^2 : 1364224
# The number is : 514089
# (x+y)^2 : 363609
# The number is : 515524
# (x+y)^2 : 1079521
# The number is : 516961
# (x+y)^2 : 2181529
# The number is : 518400
# (x+y)^2 : 842724
# The number is : 519841
# (x+y)^2 : 1849600
# The number is : 521284
# (x+y)^2 : 648025
# The number is : 522729
# (x+y)^2 : 1565001
# The number is : 524176
# (x+y)^2 : 490000
# The number is : 525625
# (x+y)^2 : 1322500
# The number is : 527076
# (x+y)^2 : 363609
# The number is : 528529
# (x+y)^2 : 1117249
# The number is : 529984
# (x+y)^2 : 2289169
# The number is : 531441
# (x+y)^2 : 944784
# The number is : 532900
# (x+y)^2 : 2050624
# The number is : 534361
# (x+y)^2 : 801025
# The number is : 535824
# (x+y)^2 : 1846881
# The number is : 537289
# (x+y)^2 : 682276
# The number is : 538756
# (x+y)^2 : 1674436
# The number is : 540225
# (x+y)^2 : 585225
# The number is : 541696
# (x+y)^2 : 1530169
# The number is : 543169
# (x+y)^2 : 506944
# The number is : 544644
# (x+y)^2 : 1411344
# The number is : 546121
# (x+y)^2 : 444889
# The number is : 547600
# (x+y)^2 : 1315609
# The number is : 549081
# (x+y)^2 : 396900
# The number is : 550564
# (x+y)^2 : 1240996
# The number is : 552049
# (x+y)^2 : 361201
# The number is : 553536
# (x+y)^2 : 1185921
# The number is : 555025
# (x+y)^2 : 336400
# The number is : 556516
# (x+y)^2 : 1149184
# The number is : 558009
# (x+y)^2 : 321489
# The number is : 559504
# (x+y)^2 : 1129969
# The number is : 561001
# (x+y)^2 : 315844
# The number is : 562500
# (x+y)^2 : 1127844
# The number is : 564001
# (x+y)^2 : 319225
# The number is : 565504
# (x+y)^2 : 1142761
# The number is : 567009
# (x+y)^2 : 331776
# The number is : 568516
# (x+y)^2 : 1175056
# The number is : 570025
# (x+y)^2 : 354025
# The number is : 571536
# (x+y)^2 : 1225449
# The number is : 573049
# (x+y)^2 : 386884
# The number is : 574564
# (x+y)^2 : 1295044
# The number is : 576081
# (x+y)^2 : 431649
# The number is : 577600
# (x+y)^2 : 1385329
# The number is : 579121
# (x+y)^2 : 490000
# The number is : 580644
# (x+y)^2 : 1498176
# The number is : 582169
# (x+y)^2 : 564001
# The number is : 583696
# (x+y)^2 : 1635841
# The number is : 585225
# (x+y)^2 : 656100
# The number is : 586756
# (x+y)^2 : 1800964
# The number is : 588289
# (x+y)^2 : 769129
# The number is : 589824
# (x+y)^2 : 1996569
# The number is : 591361
# (x+y)^2 : 906304
# The number is : 592900
# (x+y)^2 : 2226064
# The number is : 594441
# (x+y)^2 : 1071225
# The number is : 595984
# (x+y)^2 : 2493241
# The number is : 597529
# (x+y)^2 : 1267876
# The number is : 599076
# (x+y)^2 : 455625
# The number is : 600625
# (x+y)^2 : 1500625
# The number is : 602176
# (x+y)^2 : 605284
# The number is : 603729
# (x+y)^2 : 1774224
# The number is : 605284
# (x+y)^2 : 790321
# The number is : 606841
# (x+y)^2 : 2093809
# The number is : 608400
# (x+y)^2 : 1016064
# The number is : 609961
# (x+y)^2 : 2464900
# The number is : 611524
# (x+y)^2 : 1288225
# The number is : 613089
# (x+y)^2 : 492804
# The number is : 614656
# (x+y)^2 : 1612900
# The number is : 616225
# (x+y)^2 : 707281
# The number is : 617796
# (x+y)^2 : 1996569
# The number is : 619369
# (x+y)^2 : 976144
# The number is : 620944
# (x+y)^2 : 2446096
# The number is : 622521
# (x+y)^2 : 1306449
# The number is : 624100
# (x+y)^2 : 524176
# The number is : 625681
# (x+y)^2 : 1705636
# The number is : 627264
# (x+y)^2 : 793881
# The number is : 628849
# (x+y)^2 : 2181529
# The number is : 630436
# (x+y)^2 : 1136356
# The number is : 632025
# (x+y)^2 : 431649
# The number is : 633616
# (x+y)^2 : 1560001
# The number is : 635209
# (x+y)^2 : 712336
# The number is : 636804
# (x+y)^2 : 2073600
# The number is : 638401
# (x+y)^2 : 1079521
# The number is : 640000
# (x+y)^2 : 409600
# The number is : 641601
# (x+y)^2 : 1542564
# The number is : 643204
# (x+y)^2 : 717409
# The number is : 644809
# (x+y)^2 : 2111209
# The number is : 646416
# (x+y)^2 : 1127844
# The number is : 648025
# (x+y)^2 : 452929
# The number is : 649636
# (x+y)^2 : 1651225
# The number is : 651249
# (x+y)^2 : 810000
# The number is : 652864
# (x+y)^2 : 2298256
# The number is : 654481
# (x+y)^2 : 1288225
# The number is : 656100
# (x+y)^2 : 571536
# The number is : 657721
# (x+y)^2 : 1898884
# The number is : 659344
# (x+y)^2 : 1006009
# The number is : 660969
# (x+y)^2 : 2653641
# The number is : 662596
# (x+y)^2 : 1582564
# The number is : 664225
# (x+y)^2 : 790321
# The number is : 665856
# (x+y)^2 : 2313441
# The number is : 667489
# (x+y)^2 : 1336336
# The number is : 669124
# (x+y)^2 : 628849
# The number is : 670761
# (x+y)^2 : 2047761
# The number is : 672400
# (x+y)^2 : 1149184
# The number is : 674041
# (x+y)^2 : 511225
# The number is : 675684
# (x+y)^2 : 1846881
# The number is : 677329
# (x+y)^2 : 1012036
# The number is : 678976
# (x+y)^2 : 2735716
# The number is : 680625
# (x+y)^2 : 1703025
# The number is : 682276
# (x+y)^2 : 917764
# The number is : 683929
# (x+y)^2 : 2598544
# The number is : 685584
# (x+y)^2 : 1610361
# The number is : 687241
# (x+y)^2 : 861184
# The number is : 688900
# (x+y)^2 : 2521744
# The number is : 690561
# (x+y)^2 : 1565001
# The number is : 692224
# (x+y)^2 : 839056
# The number is : 693889
# (x+y)^2 : 2502724
# The number is : 695556
# (x+y)^2 : 1565001
# The number is : 697225
# (x+y)^2 : 850084
# The number is : 698896
# (x+y)^2 : 2540836
# The number is : 700569
# (x+y)^2 : 1610361
# The number is : 702244
# (x+y)^2 : 894916
# The number is : 703921
# (x+y)^2 : 2637376
# The number is : 705600
# (x+y)^2 : 1703025
# The number is : 707281
# (x+y)^2 : 976144
# The number is : 708964
# (x+y)^2 : 2795584
# The number is : 710649
# (x+y)^2 : 1846881
# The number is : 712336
# (x+y)^2 : 1098304
# The number is : 714025
# (x+y)^2 : 546121
# The number is : 715716
# (x+y)^2 : 2047761
# The number is : 717409
# (x+y)^2 : 1267876
# The number is : 719104
# (x+y)^2 : 677329
# The number is : 720801
# (x+y)^2 : 2313441
# The number is : 722500
# (x+y)^2 : 1493284
# The number is : 724201
# (x+y)^2 : 855625
# The number is : 725904
# (x+y)^2 : 2653641
# The number is : 727609
# (x+y)^2 : 1784896
# The number is : 729316
# (x+y)^2 : 1092025
# The number is : 731025
# (x+y)^2 : 571536
# The number is : 732736
# (x+y)^2 : 2155024
# The number is : 734449
# (x+y)^2 : 1399489
# The number is : 736164
# (x+y)^2 : 810000
# The number is : 737881
# (x+y)^2 : 2617924
# The number is : 739600
# (x+y)^2 : 1792921
# The number is : 741321
# (x+y)^2 : 1127844
# The number is : 743044
# (x+y)^2 : 619369
# The number is : 744769
# (x+y)^2 : 2289169
# The number is : 746496
# (x+y)^2 : 1542564
# The number is : 748225
# (x+y)^2 : 946729
# The number is : 749956
# (x+y)^2 : 2907025
# The number is : 751689
# (x+y)^2 : 2073600
# The number is : 753424
# (x+y)^2 : 1385329
# The number is : 755161
# (x+y)^2 : 839056
# The number is : 756900
# (x+y)^2 : 2742336
# The number is : 758641
# (x+y)^2 : 1957201
# The number is : 760384
# (x+y)^2 : 1308736
# The number is : 762129
# (x+y)^2 : 793881
# The number is : 763876
# (x+y)^2 : 2686321
# The number is : 765625
# (x+y)^2 : 1932100
# The number is : 767376
# (x+y)^2 : 1306449
# The number is : 769129
# (x+y)^2 : 806404
# The number is : 770884
# (x+y)^2 : 2735716
# The number is : 772641
# (x+y)^2 : 1996569
# The number is : 774400
# (x+y)^2 : 1378276
# The number is : 776161
# (x+y)^2 : 877969
# The number is : 777924
# (x+y)^2 : 2893401
# The number is : 779689
# (x+y)^2 : 2155024
# The number is : 781456
# (x+y)^2 : 1530169
# The number is : 783225
# (x+y)^2 : 1016064
# The number is : 784996
# (x+y)^2 : 3168400
# The number is : 786769
# (x+y)^2 : 2418025
# The number is : 788544
# (x+y)^2 : 1774224
# The number is : 790321
# (x+y)^2 : 1234321
# The number is : 792100
# (x+y)^2 : 795664
# The number is : 793881
# (x+y)^2 : 2802276
# The number is : 795664
# (x+y)^2 : 2128681
# The number is : 797449
# (x+y)^2 : 1552516
# The number is : 799236
# (x+y)^2 : 1071225
# The number is : 801025
# (x+y)^2 : 682276
# The number is : 802816
# (x+y)^2 : 2617924
# The number is : 804609
# (x+y)^2 : 1996569
# The number is : 806404
# (x+y)^2 : 1464100
# The number is : 808201
# (x+y)^2 : 1018081
# The number is : 810000
# (x+y)^2 : 656100
# The number is : 811801
# (x+y)^2 : 2598544
# The number is : 813604
# (x+y)^2 : 2007889
# The number is : 815409
# (x+y)^2 : 1498176
# The number is : 817216
# (x+y)^2 : 1067089
# The number is : 819025
# (x+y)^2 : 712336
# The number is : 820836
# (x+y)^2 : 2742336
# The number is : 822649
# (x+y)^2 : 2163841
# The number is : 824464
# (x+y)^2 : 1658944
# The number is : 826281
# (x+y)^2 : 1225449
# The number is : 828100
# (x+y)^2 : 861184
# The number is : 829921
# (x+y)^2 : 3062500
# The number is : 831744
# (x+y)^2 : 2480625
# The number is : 833569
# (x+y)^2 : 1965604
# The number is : 835396
# (x+y)^2 : 1515361
# The number is : 837225
# (x+y)^2 : 1127844
# The number is : 839056
# (x+y)^2 : 801025
# The number is : 840889
# (x+y)^2 : 2989441
# The number is : 842724
# (x+y)^2 : 2452356
# The number is : 844561
# (x+y)^2 : 1974025
# The number is : 846400
# (x+y)^2 : 1552516
# The number is : 848241
# (x+y)^2 : 1185921
# The number is : 850084
# (x+y)^2 : 872356
# The number is : 851929
# (x+y)^2 : 3168400
# The number is : 853776
# (x+y)^2 : 2653641
# The number is : 855625
# (x+y)^2 : 2190400
# The number is : 857476
# (x+y)^2 : 1776889
# The number is : 859329
# (x+y)^2 : 1411344
# The number is : 861184
# (x+y)^2 : 1092025
# The number is : 863041
# (x+y)^2 : 817216
# The number is : 864900
# (x+y)^2 : 3111696
# The number is : 866761
# (x+y)^2 : 2647129
# The number is : 868624
# (x+y)^2 : 2226064
# The number is : 870489
# (x+y)^2 : 1846881
# The number is : 872356
# (x+y)^2 : 1507984
# The number is : 874225
# (x+y)^2 : 1207801
# The number is : 876096
# (x+y)^2 : 944784
# The number is : 877969
# (x+y)^2 : 3407716
# The number is : 879844
# (x+y)^2 : 2968729
# The number is : 881721
# (x+y)^2 : 2566404
# The number is : 883600
# (x+y)^2 : 2199289
# The number is : 885481
# (x+y)^2 : 1865956
# The number is : 887364
# (x+y)^2 : 1565001
# The number is : 889249
# (x+y)^2 : 1295044
# The number is : 891136
# (x+y)^2 : 1054729
# The number is : 893025
# (x+y)^2 : 842724
# The number is : 894916
# (x+y)^2 : 3276100
# The number is : 896809
# (x+y)^2 : 2907025
# The number is : 898704
# (x+y)^2 : 2566404
# The number is : 900601
# (x+y)^2 : 2253001
# The number is : 902500
# (x+y)^2 : 1965604
# The number is : 904401
# (x+y)^2 : 1703025
# The number is : 906304
# (x+y)^2 : 1464100
# The number is : 908209
# (x+y)^2 : 1247689
# The number is : 910116
# (x+y)^2 : 1052676
# The number is : 912025
# (x+y)^2 : 877969
# The number is : 913936
# (x+y)^2 : 3418801
# The number is : 915849
# (x+y)^2 : 3111696
# The number is : 917764
# (x+y)^2 : 2825761
# The number is : 919681
# (x+y)^2 : 2560000
# The number is : 921600
# (x+y)^2 : 2313441
# The number is : 923521
# (x+y)^2 : 2085136
# The number is : 925444
# (x+y)^2 : 1874161
# The number is : 927369
# (x+y)^2 : 1679616
# The number is : 929296
# (x+y)^2 : 1500625
# The number is : 931225
# (x+y)^2 : 1336336
# The number is : 933156
# (x+y)^2 : 1185921
# The number is : 935089
# (x+y)^2 : 1048576
# The number is : 937024
# (x+y)^2 : 923521
# The number is : 938961
# (x+y)^2 : 3606201
# The number is : 940900
# (x+y)^2 : 3385600
# The number is : 942841
# (x+y)^2 : 3179089
# The number is : 944784
# (x+y)^2 : 2985984
# The number is : 946729
# (x+y)^2 : 2805625
# The number is : 948676
# (x+y)^2 : 2637376
# The number is : 950625
# (x+y)^2 : 2480625
# The number is : 952576
# (x+y)^2 : 2334784
# The number is : 954529
# (x+y)^2 : 2199289
# The number is : 956484
# (x+y)^2 : 2073600
# The number is : 958441
# (x+y)^2 : 1957201
# The number is : 960400
# (x+y)^2 : 1849600
# The number is : 962361
# (x+y)^2 : 1750329
# The number is : 964324
# (x+y)^2 : 1658944
# The number is : 966289
# (x+y)^2 : 1575025
# The number is : 968256
# (x+y)^2 : 1498176
# The number is : 970225
# (x+y)^2 : 1428025
# The number is : 972196
# (x+y)^2 : 1364224
# The number is : 974169
# (x+y)^2 : 1306449
# The number is : 976144
# (x+y)^2 : 1254400
# The number is : 978121
# (x+y)^2 : 1207801
# The number is : 980100
# (x+y)^2 : 1166400
# The number is : 982081
# (x+y)^2 : 1129969
# The number is : 984064
# (x+y)^2 : 1098304
# The number is : 986049
# (x+y)^2 : 1071225
# The number is : 988036
# (x+y)^2 : 1048576
# The number is : 990025
# (x+y)^2 : 1030225
# The number is : 992016
# (x+y)^2 : 1016064
# The number is : 994009
# (x+y)^2 : 1006009
# The number is : 996004
# (x+y)^2 : 1000000
# The number is : 998001
# (x+y)^2 : 998001
# true
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20864/101705561.py in <module>
#       4
#       5 while i<=K:
# ----> 6  value1= str(listN[i])
#       7  print("The number is : " + str(value1))
#       8  length = len(str(value1))
#
# IndexError: list index out of range
